# %%
shot = 58583
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
# Extracting files for shot 58583 to /Home/difdop/DBSdata/tmp/west...
# Extraction complete.
#
# shot       = 58583
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58583
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'T_e'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/Bureau/Analysis/profs.py in <module>
#       <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=88'>89</a> summary, ece = time_trace(shot)
#       <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=89'>90</a> tstart, tend = min(summary.time), max(summary.time)
# ----> <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=90'>91</a> plot_tt(shot, summary, ece, tstart, tend)
#
# ~/Bureau/Analysis/profs.py in plot_tt(shot, summary, ece, tstart, tend, save)
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=48'>49</a>     ax.plot(summary['time'], summary['p_lh']*1e-6, 'orange', label = r'$P_{LH}$ [MW]') #MW
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=49'>50</a>     ax.plot(summary['time'], summary.p_ohm*1e-6, 'teal', label = r'$P_{Ohm}$ [MW]') #MW
# ---> <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=50'>51</a>     ax.plot(ece['time_ece'], ece['T_e']*1e-3, 'dodgerblue', label = r'$T_{e0}$ [eV]') #eV
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=51'>52</a>     ax.grid(c = 'silver', ls ='--', lw = 0.5)
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=52'>53</a>     ax.legend(loc = 'center left', bbox_to_anchor = (1, 0.5))
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'T_e'

# %%
shot = 58566
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
#
# shot       = 58566
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58566
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'T_e'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/Bureau/Analysis/profs.py in <module>
#       <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=88'>89</a> summary, ece = time_trace(shot)
#       <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=89'>90</a> tstart, tend = min(summary.time), max(summary.time)
# ----> <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=90'>91</a> plot_tt(shot, summary, ece, tstart, tend)
#
# ~/Bureau/Analysis/profs.py in plot_tt(shot, summary, ece, tstart, tend, save)
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=48'>49</a>     ax.plot(summary['time'], summary['p_lh']*1e-6, 'orange', label = r'$P_{LH}$ [MW]') #MW
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=49'>50</a>     ax.plot(summary['time'], summary.p_ohm*1e-6, 'teal', label = r'$P_{Ohm}$ [MW]') #MW
# ---> <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=50'>51</a>     ax.plot(ece['time_ece'], ece['T_e']*1e-3, 'dodgerblue', label = r'$T_{e0}$ [eV]') #eV
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=51'>52</a>     ax.grid(c = 'silver', ls ='--', lw = 0.5)
#      <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=52'>53</a>     ax.legend(loc = 'center left', bbox_to_anchor = (1, 0.5))
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /Applications/software/anaconda/python37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'T_e'

# %%
machine = 'west'
def plot_tt(shot, summary, ece, tstart, tend, save = False):
    global machine, gnr_path_timetraces
    
    fig, ax = plt.subplots( figsize = (15, 4))
    ax.set_title('SHOT #%d' %shot,  size = 18)
    t, anglepol = get_angle_pol(machine, shot, tstart, tend, return_val='array')
    
    ax.plot(t, anglepol, 'silver', lw = 0.8, label = r'$\alpha$ [rad]')
    ax.legend(loc = 'center left', bbox_to_anchor = (1, 0.5))
    ax.grid(c = 'silver', ls ='--', lw = 0.5)
    ax.set_xlabel('time [s]')
    
    ax.plot(summary['time'], -summary['ip']/2*1e-5, 'magenta', label = r'$I_p$ [200kA]') #200kA
    ax.plot(summary['time'], summary['n_e']*1e-19, 'lime', label = r'$\overline{n_e}$ [$10^{19}$ $m^{-3}$]') #1e19
    ax.plot(summary['time'], summary['p_ic']*1e-6, 'red', label = r'$P_{ICRH}$ [MW]') #MW
    ax.plot(summary['time'], summary['p_lh']*1e-6, 'orange', label = r'$P_{LH}$ [MW]') #MW
    ax.plot(summary['time'], summary.p_ohm*1e-6, 'teal', label = r'$P_{Ohm}$ [MW]') #MW
    ax.plot(ece['time_ece'], ece['T_e']*1e-3, 'dodgerblue', label = r'$T_{e0}$ [eV]') #eV
    ax.grid(c = 'silver', ls ='--', lw = 0.5)
    ax.legend(loc = 'center left', bbox_to_anchor = (1, 0.5))
    ax.set_xlabel('time [s]')
    ax.set_xlim(min(summary.time) - 0.5,max(summary.time) + 0.5)

    if save == True:
        save_fig1 = gnr_path_timetraces1.format(shot)
        save_fig2 = gnr_path_timetraces2.format(shot)
        plt.savefig(save_fig1)
        plt.savefig(save_fig2)
    plt.show()
    
def time_trace(shot):
    t_ignitron = pw.tsbase(shot, 'RIGNITRON')[0][0,0]
    summ = imas_west.get(shot, 'summary')
    ece = imas_west.get(shot, 'ece')
    
    summary_df = pd.DataFrame()
    summary_df['time'] = summ.time - t_ignitron 
    summary_df['ip'] = summ.global_quantities.ip.value 
    summary_df['p_ohm'] = summ.global_quantities.power_ohm.value 
    summary_df['n_e'] = summ.line_average.n_e.value 
    summary_df['p_ic'] = summ.heating_current_drive.power_ic.value 
    summary_df['p_lh'] = summ.heating_current_drive.power_lh.value 

    ece_df = pd.DataFrame()
    ece_df['time_ece'] = ece.time - t_ignitron
    ece_df['T_e'] = ece.t_e_central.data
    
    
    
    return summary_df, ece_df

# %%
shot = 58566
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
#
# shot       = 58566
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58566
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west

# %%
shot = 58540
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
# Extracting files for shot 58540 to /Home/difdop/DBSdata/tmp/west...
# Extraction complete.
#
# shot       = 58540
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58540
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west

# %%
#dataI = DataInterface(shot, isweep='False', channelval=1, machine='west')
dataI = DataInterface(shot, channelval=1, machine='west')
params = dataI.params

t_acq = params.TDIFDOP + params.t0seq         

t, anglepol = get_angle_pol(machine, shot, tstart, tend, return_val='array')

fig, ax = plt.subplots(figsize = (10,4))
ax.plot(t , anglepol, label = r'$\alpha$ [rad]')
ax.plot(np.linspace(0,35,100), 6*np.ones(100), 'red')
ax.legend(loc = 'center left', bbox_to_anchor = (1, 0.5))
#for i in range(0, len(t_acq), 10):
#   ax.plot(t_acq[i]*np.ones(100), np.linspace(min(anglepol), max(anglepol), 100), 'gray', '-.')
#ax.plot(t_acq[52]*np.ones(100), np.linspace(min(anglepol), max(anglepol), 100), 'gray', '-')
#ax.plot(t_acq[]*np.ones(100), np.linspace(min(anglepol), max(anglepol), 100), 'gray', '-')

ax.grid(c = 'silver', ls ='--', lw = 0.5)
ax.set_xlabel('time [s]')
#ax.set_xlim(27,28)
plt.show()
# Out:
# 125 Sequences of 200.0 ms at time
#     1            10
#     2            10.2
#     3            10.4
#     4            10.6
#     5            10.8
#     6            11
#     7            11.2
#     8            11.4
#     9            11.6
#    10            11.8
#    11            12
#    12            12.2
#    13            12.4
#    14            12.6
#    15            12.8
#    16            13
#    17            13.2
#    18            13.4
#    19            13.6
#    20            13.8
#    21            14
#    22            14.2
#    23            14.4
#    24            14.6
#    25            14.8
#    26            15
#    27            15.2
#    28            15.4
#    29            15.6
#    30            15.8
#    31            16
#    32            16.2
#    33            16.4
#    34            16.6
#    35            16.8
#    36            17
#    37            17.2
#    38            17.4
#    39            17.6
#    40            17.8
#    41            18
#    42            18.2
#    43            18.4
#    44            18.6
#    45            18.8
#    46            19
#    47            19.2
#    48            19.4
#    49            19.6
#    50            19.8
#    51            20
#    52            20.2
#    53            20.4
#    54            20.6
#    55            20.8
#    56            21
#    57            21.2
#    58            21.4
#    59            21.6
#    60            21.8
#    61            22
#    62            22.2
#    63            22.4
#    64            22.6
#    65            22.8
#    66            23
#    67            23.2
#    68            23.4
#    69            23.6
#    70            23.8
#    71            24
#    72            24.2
#    73            24.4
#    74            24.6
#    75            24.8
#    76            25
#    77            25.2
#    78            25.4
#    79            25.6
#    80            25.8
#    81            26
#    82            26.2
#    83            26.4
#    84            26.6
#    85            26.8
#    86            27
#    87            27.2
#    88            27.4
#    89            27.6
#    90            27.8
#    91            28
#    92            28.2
#    93            28.4
#    94            28.6
#    95            28.8
#    96            29
#    97            29.2
#    98            29.4
#    99            29.6
#    100            29.8
#    101            30
#    102            30.2
#    103            30.4
#    104            30.6
#    105            30.8
#    106            31
#    107            31.2
#    108            31.4
#    109            31.6
#    110            31.8
#    111            32
#    112            32.2
#    113            32.4
#    114            32.6
#    115            32.8
#    116            33
#    117            33.2
#    118            33.4
#    119            33.6
#    120            33.8
#    121            34
#    122            34.2
#    123            34.4
#    124            34.6
#    125            34.8

# %%
plt.plot(params.F, '.')

# %%
plt.plotnp.linspace(1, len(params.F), len(para,s.F), (params.F, '.')
# Out:
#   File "<ipython-input-22-e04fc6ac5e9c>", line 2
#     plt.plotnp.linspace(1, len(params.F), len(para,s.F), (params.F, '.')
#                                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.plotnp.linspace(1, len(params.F), len(para,s.F), params.F, '.' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Bureau/Analysis/profs.py in <module>
#       <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=138'>139</a> # %%
# ----> <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=139'>140</a> plt.plotnp.linspace(1, len(params.F), len(para,s.F), params.F, '.' )
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'plotnp'

# %%
plt.plot(np.linspace(1, len(params.F), len(para,s.F)), params.F, '.' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Bureau/Analysis/profs.py in <module>
#       <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=138'>139</a> # %%
# ----> <a href='file:///Home/FO278650/Bureau/Analysis/profs.py?line=139'>140</a> plt.plot(np.linspace(1, len(params.F), len(para,s.F)), params.F, '.' )
#
# NameError: name 'para' is not defined

# %%
plt.plot(np.linspace(1, len(params.F), len(params.F)), params.F, '.' )

# %%
shot = 58595
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
#
# shot       = 58595
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58595
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west

# %%
dataI = DataInterface(shot, channelval=2, machine='west')
params = dataI.params
plt.plot(np.linspace(1, len(params.F), len(params.F)), params.F, '.' )
# Out:
# 100 Sequences of 300.0 ms at time
#     1            10
#     2            10.3
#     3            10.6
#     4            10.9
#     5            11.2
#     6            11.5
#     7            11.8
#     8            12.1
#     9            12.4
#    10            12.7
#    11            13
#    12            13.3
#    13            13.6
#    14            13.9
#    15            14.2
#    16            14.5
#    17            14.8
#    18            15.1
#    19            15.4
#    20            15.7
#    21            16
#    22            16.3
#    23            16.6
#    24            16.9
#    25            17.2
#    26            17.5
#    27            17.8
#    28            18.1
#    29            18.4
#    30            18.7
#    31            19
#    32            19.3
#    33            19.6
#    34            19.9
#    35            20.2
#    36            20.5
#    37            20.8
#    38            21.1
#    39            21.4
#    40            21.7
#    41            22
#    42            22.3
#    43            22.6
#    44            22.9
#    45            23.2
#    46            23.5
#    47            23.8
#    48            24.1
#    49            24.4
#    50            24.7
#    51            25
#    52            25.3
#    53            25.6
#    54            25.9
#    55            26.2
#    56            26.5
#    57            26.8
#    58            27.1
#    59            27.4
#    60            27.7
#    61            28
#    62            28.3
#    63            28.6
#    64            28.9
#    65            29.2
#    66            29.5
#    67            29.8
#    68            30.1
#    69            30.4
#    70            30.7
#    71            31
#    72            31.3
#    73            31.6
#    74            31.9
#    75            32.2
#    76            32.5
#    77            32.8
#    78            33.1
#    79            33.4
#    80            33.7
#    81            34
#    82            34.3
#    83            34.6
#    84            34.9
#    85            35.2
#    86            35.5
#    87            35.8
#    88            36.1
#    89            36.4
#    90            36.7
#    91            37
#    92            37.3
#    93            37.6
#    94            37.9
#    95            38.2
#    96            38.5
#    97            38.8
#    98            39.1
#    99            39.4
#    100            39.7

# %%
dataI = DataInterface(58594, channelval=2, machine='west')
params = dataI.params
plt.plot(np.linspace(1, len(params.F), len(params.F)), params.F, '.' )
# Out:
# 100 Sequences of 300.0 ms at time
#     1            10
#     2            10.3
#     3            10.6
#     4            10.9
#     5            11.2
#     6            11.5
#     7            11.8
#     8            12.1
#     9            12.4
#    10            12.7
#    11            13
#    12            13.3
#    13            13.6
#    14            13.9
#    15            14.2
#    16            14.5
#    17            14.8
#    18            15.1
#    19            15.4
#    20            15.7
#    21            16
#    22            16.3
#    23            16.6
#    24            16.9
#    25            17.2
#    26            17.5
#    27            17.8
#    28            18.1
#    29            18.4
#    30            18.7
#    31            19
#    32            19.3
#    33            19.6
#    34            19.9
#    35            20.2
#    36            20.5
#    37            20.8
#    38            21.1
#    39            21.4
#    40            21.7
#    41            22
#    42            22.3
#    43            22.6
#    44            22.9
#    45            23.2
#    46            23.5
#    47            23.8
#    48            24.1
#    49            24.4
#    50            24.7
#    51            25
#    52            25.3
#    53            25.6
#    54            25.9
#    55            26.2
#    56            26.5
#    57            26.8
#    58            27.1
#    59            27.4
#    60            27.7
#    61            28
#    62            28.3
#    63            28.6
#    64            28.9
#    65            29.2
#    66            29.5
#    67            29.8
#    68            30.1
#    69            30.4
#    70            30.7
#    71            31
#    72            31.3
#    73            31.6
#    74            31.9
#    75            32.2
#    76            32.5
#    77            32.8
#    78            33.1
#    79            33.4
#    80            33.7
#    81            34
#    82            34.3
#    83            34.6
#    84            34.9
#    85            35.2
#    86            35.5
#    87            35.8
#    88            36.1
#    89            36.4
#    90            36.7
#    91            37
#    92            37.3
#    93            37.6
#    94            37.9
#    95            38.2
#    96            38.5
#    97            38.8
#    98            39.1
#    99            39.4
#    100            39.7

# %%
dataI = DataInterface(58595, channelval=2, machine='west')
params = dataI.params
plt.plot(np.linspace(1, len(params.F), len(params.F)), params.F, '.' )
# Out:
# 100 Sequences of 300.0 ms at time
#     1            10
#     2            10.3
#     3            10.6
#     4            10.9
#     5            11.2
#     6            11.5
#     7            11.8
#     8            12.1
#     9            12.4
#    10            12.7
#    11            13
#    12            13.3
#    13            13.6
#    14            13.9
#    15            14.2
#    16            14.5
#    17            14.8
#    18            15.1
#    19            15.4
#    20            15.7
#    21            16
#    22            16.3
#    23            16.6
#    24            16.9
#    25            17.2
#    26            17.5
#    27            17.8
#    28            18.1
#    29            18.4
#    30            18.7
#    31            19
#    32            19.3
#    33            19.6
#    34            19.9
#    35            20.2
#    36            20.5
#    37            20.8
#    38            21.1
#    39            21.4
#    40            21.7
#    41            22
#    42            22.3
#    43            22.6
#    44            22.9
#    45            23.2
#    46            23.5
#    47            23.8
#    48            24.1
#    49            24.4
#    50            24.7
#    51            25
#    52            25.3
#    53            25.6
#    54            25.9
#    55            26.2
#    56            26.5
#    57            26.8
#    58            27.1
#    59            27.4
#    60            27.7
#    61            28
#    62            28.3
#    63            28.6
#    64            28.9
#    65            29.2
#    66            29.5
#    67            29.8
#    68            30.1
#    69            30.4
#    70            30.7
#    71            31
#    72            31.3
#    73            31.6
#    74            31.9
#    75            32.2
#    76            32.5
#    77            32.8
#    78            33.1
#    79            33.4
#    80            33.7
#    81            34
#    82            34.3
#    83            34.6
#    84            34.9
#    85            35.2
#    86            35.5
#    87            35.8
#    88            36.1
#    89            36.4
#    90            36.7
#    91            37
#    92            37.3
#    93            37.6
#    94            37.9
#    95            38.2
#    96            38.5
#    97            38.8
#    98            39.1
#    99            39.4
#    100            39.7

# %%
shot = 58529
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
#
# shot       = 58529
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58529
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west

# %%
shot = 58525
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
#
# shot       = 58525
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58525
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west

# %%
shot = 58540
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
#
# shot       = 58540
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58540
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west

# %%
shot = 58595
_ = extract_DBS_files(shot, machine=machine,  extract_all=True)

summary, ece = time_trace(shot)
tstart, tend = min(summary.time), max(summary.time)
plot_tt(shot, summary, ece, tstart, tend)
# Out:
#
# shot       = 58595
# ids_name   = summary
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west
#
#
# shot       = 58595
# ids_name   = ece
# run        = 0
# occurrence = 0
# user       = imas_public
# machine    = west

# %%
dataI = DataInterface(58595, channelval=2, machine='west')
params = dataI.params
plt.plot(np.linspace(1, len(params.F), len(params.F)), params.F, '.' )
# Out:
# 100 Sequences of 300.0 ms at time
#     1            10
#     2            10.3
#     3            10.6
#     4            10.9
#     5            11.2
#     6            11.5
#     7            11.8
#     8            12.1
#     9            12.4
#    10            12.7
#    11            13
#    12            13.3
#    13            13.6
#    14            13.9
#    15            14.2
#    16            14.5
#    17            14.8
#    18            15.1
#    19            15.4
#    20            15.7
#    21            16
#    22            16.3
#    23            16.6
#    24            16.9
#    25            17.2
#    26            17.5
#    27            17.8
#    28            18.1
#    29            18.4
#    30            18.7
#    31            19
#    32            19.3
#    33            19.6
#    34            19.9
#    35            20.2
#    36            20.5
#    37            20.8
#    38            21.1
#    39            21.4
#    40            21.7
#    41            22
#    42            22.3
#    43            22.6
#    44            22.9
#    45            23.2
#    46            23.5
#    47            23.8
#    48            24.1
#    49            24.4
#    50            24.7
#    51            25
#    52            25.3
#    53            25.6
#    54            25.9
#    55            26.2
#    56            26.5
#    57            26.8
#    58            27.1
#    59            27.4
#    60            27.7
#    61            28
#    62            28.3
#    63            28.6
#    64            28.9
#    65            29.2
#    66            29.5
#    67            29.8
#    68            30.1
#    69            30.4
#    70            30.7
#    71            31
#    72            31.3
#    73            31.6
#    74            31.9
#    75            32.2
#    76            32.5
#    77            32.8
#    78            33.1
#    79            33.4
#    80            33.7
#    81            34
#    82            34.3
#    83            34.6
#    84            34.9
#    85            35.2
#    86            35.5
#    87            35.8
#    88            36.1
#    89            36.4
#    90            36.7
#    91            37
#    92            37.3
#    93            37.6
#    94            37.9
#    95            38.2
#    96            38.5
#    97            38.8
#    98            39.1
#    99            39.4
#    100            39.7
